# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

def simulate_erdos_renyi(n, p, seed=None):
    G = nx.erdos_renyi_graph(n=n, p=p, seed=seed)
    return G

def analyze_graph(G):
    results = {
        "nodes": G.number_of_nodes(),
        "edges": G.number_of_edges(),
        "density": nx.density(G),
        "avg_degree": sum(dict(G.degree()).values()) / G.number_of_nodes(),
        "connected": nx.is_connected(G),
        "components": nx.number_connected_components(G),
        "diameter": nx.diameter(G) if nx.is_connected(G) else float('inf'),
        "avg_path_length": nx.average_shortest_path_length(G) if nx.is_connected(G) else float('inf'),
        "clustering_coefficient": nx.average_clustering(G)
    }
    
    return results

def visualize_graph(G, title=None, figsize=(10, 8)):
    plt.figure(figsize=figsize)
    
    pos = nx.spring_layout(G, seed=42)
    

    nx.draw_networkx_nodes(G, pos, node_size=300, node_color='lightblue')
    nx.draw_networkx_edges(G, pos, alpha=0.3)
    nx.draw_networkx_labels(G, pos, font_size=10)
    
    plt.title(title)
    plt.axis('off')
    plt.tight_layout()
    plt.show()

# Example usage
if __name__ == "__main__":
     
  
    G = simulate_erdos_renyi(20, 0.2, seed=42)
    
    
    properties = analyze_graph(G)
    print("Graph Properties:")
    for prop, value in properties.items():
        print(f"- {prop}: {value}")
    
    # Visualize the graph
    visualize_graph(G, title=f"Erdos-Renyi Graph G({20}, {0.2})")
# Out:
# Graph Properties:
# - nodes: 20
# - edges: 37
# - density: 0.19473684210526315
# - avg_degree: 3.7
# - connected: False
# - components: 2
# - diameter: inf
# - avg_path_length: inf
# - clustering_coefficient: 0.1530952380952381
